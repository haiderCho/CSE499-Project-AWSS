# %% [markdown]
# # Using Yolov8 Model

# %% [markdown]
# Here we have mount our google drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Install the necessary library.

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# Setup complete ✅ (12 CPUs, 53.0 GB RAM, 32.6/235.7 GB disk)

# %%
# %cd /content/drive/MyDrive/waste
# Out:
# /content/drive/MyDrive/waste

# %%
# !ls
# Out:
# runs  waste-detection-10  yolo11n.pt  yolo_training.ipynb  yolov8m.pt  yolov8s.pt

# %% [markdown]
# Fetch the dataset through roboflow api.

# %%
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="vGyg6wDkOV7aQEHbl9ay")
project = rf.workspace("ai-project-i3wje").project("waste-detection-vqkjo")
version = project.version(10)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to waste-detection-10 in yolov8:: 100%|██████████| 31936/31936 [03:32<00:00, 150.06it/s]

# %% [markdown]
# Training YOLOV8s model command.

# %%
# !yolo task=detect model=train model=yolov8s.pt data=/content/drive/MyDrive/waste/waste-detection-10/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# WARNING ⚠️ 'mode' argument is missing. Valid modes are {'export', 'benchmark', 'train', 'track', 'val', 'predict'}. Using default 'mode=train'.
# ...
# 100% 21.5M/21.5M [00:00<00:00, 320MB/s]
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (NVIDIA L4, 22700MiB)
# ...
